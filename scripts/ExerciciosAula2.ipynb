# %%
from si.data.dataset import Dataset
from si.io.csv_file import read_csv
from si.feature_selection.select_percentile import SelectPercentile as sp

# %%
ficheiroIris = read_csv('C:\\Percurso Académico\\Mestrado em Bioinformática - UMinho\\2023-2024\\02 Disciplinas\\1º Semestre\\03 Sistemas Inteligentes para a Bioinformática\\si\\datasets\\iris\\iris.csv', features=True, label=True)


transformDataset = sp(0.1).fit(ficheiroIris)
print("Fit F\n")
print(transformDataset.F)
print("\nFit p\n")
print(transformDataset.p)
print("\nTransform\n")
transformDataset = sp(0.1).transform(ficheiroIris)
print(transformDataset.X)
print("\nFit_Transform\n")
transformDataset = sp(0.1).fit_transform(ficheiroIris)
print(transformDataset.X)
# Out:
# Fit F
#
# [ 119.26450218   47.3644614  1179.0343277   959.32440573]
#
# Fit p
#
# [1.66966919e-31 1.32791652e-16 3.05197580e-91 4.37695696e-85]
#
# Transform
#
# [[5.1]
#  [4.9]
#  [4.7]
#  [4.6]
#  [5. ]
#  [5.4]
#  [4.6]
#  [5. ]
#  [4.4]
#  [4.9]
#  [5.4]
#  [4.8]
#  [4.8]
#  [4.3]
#  [5.8]
#  [5.7]
#  [5.4]
#  [5.1]
#  [5.7]
#  [5.1]
#  [5.4]
#  [5.1]
#  [4.6]
#  [5.1]
#  [4.8]
#  [5. ]
#  [5. ]
#  [5.2]
#  [5.2]
#  [4.7]
#  [4.8]
#  [5.4]
#  [5.2]
#  [5.5]
#  [4.9]
#  [5. ]
#  [5.5]
#  [4.9]
#  [4.4]
#  [5.1]
#  [5. ]
#  [4.5]
#  [4.4]
#  [5. ]
#  [5.1]
#  [4.8]
#  [5.1]
#  [4.6]
#  [5.3]
#  [5. ]
#  [7. ]
#  [6.4]
#  [6.9]
#  [5.5]
#  [6.5]
#  [5.7]
#  [6.3]
#  [4.9]
#  [6.6]
#  [5.2]
#  [5. ]
#  [5.9]
#  [6. ]
#  [6.1]
#  [5.6]
#  [6.7]
#  [5.6]
#  [5.8]
#  [6.2]
#  [5.6]
#  [5.9]
#  [6.1]
#  [6.3]
#  [6.1]
#  [6.4]
#  [6.6]
#  [6.8]
#  [6.7]
#  [6. ]
#  [5.7]
#  [5.5]
#  [5.5]
#  [5.8]
#  [6. ]
#  [5.4]
#  [6. ]
#  [6.7]
#  [6.3]
#  [5.6]
#  [5.5]
#  [5.5]
#  [6.1]
#  [5.8]
# ...
